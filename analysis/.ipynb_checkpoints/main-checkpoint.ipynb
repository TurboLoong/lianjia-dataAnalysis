# %%
import pandas as pd
houses = pd.read_csv('../Lianjia_project.csv', names= ['housecode', 'name', 'line', 'station', 'residential', 'area', 'type', 'houseArea',
            'orientation', 'decoration', 'floor', 'buildingTime', 'buildingType', 'follow',
            'unitPrice', 'totalPrice', 'tags', 'href', 'elevator', 'tradeProperty', 'farFromStation'])

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73900 entries, 0 to 73899
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   housecode       73900 non-null  int64
#  1   name            73900 non-null  object
#  2   line            73900 non-null  object
#  3   station         73900 non-null  object
#  4   residential     73900 non-null  object
#  5   area            73900 non-null  object
#  6   type            73900 non-null  object
#  7   houseArea       73900 non-null  float64
#  8   orientation     73900 non-null  object
#  9   decoration      73900 non-null  object
#  10  floor           73900 non-null  object
#  11  buildingTime    68269 non-null  float64
#  12  buildingType    73900 non-null  object
#  13  follow          73900 non-null  int64
#  14  unitPrice       73900 non-null  float64
#  15  totalPrice      73900 non-null  float64
#  16  tags            73730 non-null  object
#  17  href            73900 non-null  object
#  18  elevator        73900 non-null  int64
#  19  tradeProperty   73900 non-null  int64
#  20  farFromStation  73900 non-null  int64
# dtypes: float64(4), int64(5), object(12)
# memory usage: 11.8+ MB

# %%
# 按housecode分组，查看重复值，因为一个地铁站可能分布在不同地铁线上，而且一个小区可能位于三个地铁三角区域内
groupbyed = houses[houses.duplicated('housecode')].groupby('housecode')

# %%
# 按降序排列，发现重复值非常多，达到18362个
groupbyed.size().sort_values(ascending=False)
# Out:
# housecode
# 106101874103    15
# 106101483165    15
# 106103765732    15
# 106102166392    15
# 106102738055    15
#                 ..
# 106103478084     1
# 106103478060     1
# 106103477946     1
# 106103477817     1
# 106103345720     1
# Length: 18362, dtype: int64

# %%
# 查看重复值最多的第一个
groupby_max_count = dict(list(groupbyed))[(106101874103)]

# %%
# 发现housecode = 106101874103 这条数据在四个站都计算了，而且在都算在了离地铁站0-500,500-800的距离内，真实是距离太升南路419，骡马市898，文殊院1010，市二医院1434，数据严重不符
groupby_max_count
# Out:
#           housecode             name          line station residential area  \
# 751    106101874103  缤纷假日标间，朝东向带小阳台。  1号线(科学城-韦家碾)    文殊院站       缤纷假日   太升路
# 1098   106101874103  缤纷假日标间，朝东向带小阳台。  1号线(科学城-韦家碾)    骡马市站       缤纷假日   太升路
# 1278   106101874103  缤纷假日标间，朝东向带小阳台。  1号线(科学城-韦家碾)    骡马市站       缤纷假日   太升路
# 7872   106101874103  缤纷假日标间，朝东向带小阳台。  1号线(五根松-韦家碾)    文殊院站       缤纷假日   太升路
# 8074   106101874103  缤纷假日标间，朝东向带小阳台。  1号线(五根松-韦家碾)    文殊院站       缤纷假日   太升路
# 8421   106101874103  缤纷假日标间，朝东向带小阳台。  1号线(五根松-韦家碾)    骡马市站       缤纷假日   太升路
# 8601   106101874103  缤纷假日标间，朝东向带小阳台。  1号线(五根松-韦家碾)    骡马市站       缤纷假日   太升路
# 32105  106101874103  缤纷假日标间，朝东向带小阳台。           3号线   市二医院站       缤纷假日   太升路
# 32333  106101874103  缤纷假日标间，朝东向带小阳台。           3号线   市二医院站       缤纷假日   太升路
# 41332  106101874103  缤纷假日标间，朝东向带小阳台。           4号线   市二医院站       缤纷假日   太升路
# 41560  106101874103  缤纷假日标间，朝东向带小阳台。           4号线   市二医院站       缤纷假日   太升路
# 42083  106101874103  缤纷假日标间，朝东向带小阳台。           4号线   太升南路站       缤纷假日   太升路
# 42344  106101874103  缤纷假日标间，朝东向带小阳台。           4号线   太升南路站       缤纷假日   太升路
# 42891  106101874103  缤纷假日标间，朝东向带小阳台。           4号线    骡马市站       缤纷假日   太升路
# 43071  106101874103  缤纷假日标间，朝东向带小阳台。           4号线    骡马市站       缤纷假日   太升路
#
#        type  houseArea orientation decoration  ... buildingTime  buildingType  \
# 751    1室0厅      46.87           东         简装  ...       2004.0            板楼
# 1098   1室0厅      46.87           东         简装  ...       2004.0            板楼
# 1278   1室0厅      46.87           东         简装  ...       2004.0            板楼
# 7872   1室0厅      46.87           东         简装  ...       2004.0            板楼
# 8074   1室0厅      46.87           东         简装  ...       2004.0            板楼
# 8421   1室0厅      46.87           东         简装  ...       2004.0            板楼
# 8601   1室0厅      46.87           东         简装  ...       2004.0            板楼
# 32105  1室0厅      46.87           东         简装  ...       2004.0            板楼
# 32333  1室0厅      46.87           东         简装  ...       2004.0            板楼
# 41332  1室0厅      46.87           东         简装  ...       2004.0            板楼
# 41560  1室0厅      46.87           东         简装  ...       2004.0            板楼
# 42083  1室0厅      46.87           东         简装  ...       2004.0            板楼
# 42344  1室0厅      46.87           东         简装  ...       2004.0            板楼
# 42891  1室0厅      46.87           东         简装  ...       2004.0            板楼
# 43071  1室0厅      46.87           东         简装  ...       2004.0            板楼
#
#       follow  unitPrice  totalPrice                tags  \
# 751        2    11095.0        52.0  subway:近地铁;vr:VR房源
# 1098       2    11095.0        52.0  subway:近地铁;vr:VR房源
# 1278       2    11095.0        52.0  subway:近地铁;vr:VR房源
# 7872       2    11095.0        52.0  subway:近地铁;vr:VR房源
# 8074       2    11095.0        52.0  subway:近地铁;vr:VR房源
# 8421       2    11095.0        52.0  subway:近地铁;vr:VR房源
# 8601       2    11095.0        52.0  subway:近地铁;vr:VR房源
# 32105      2    11095.0        52.0  subway:近地铁;vr:VR房源
# 32333      2    11095.0        52.0  subway:近地铁;vr:VR房源
# 41332      2    11095.0        52.0  subway:近地铁;vr:VR房源
# 41560      2    11095.0        52.0  subway:近地铁;vr:VR房源
# 42083      2    11095.0        52.0  subway:近地铁;vr:VR房源
# 42344      2    11095.0        52.0  subway:近地铁;vr:VR房源
# 42891      2    11095.0        52.0  subway:近地铁;vr:VR房源
# 43071      2    11095.0        52.0  subway:近地铁;vr:VR房源
#
#                                                     href elevator  \
# 751    https://cd.lianjia.com/ershoufang/106101874103...        2
# 1098   https://cd.lianjia.com/ershoufang/106101874103...        2
# 1278   https://cd.lianjia.com/ershoufang/106101874103...        2
# 7872   https://cd.lianjia.com/ershoufang/106101874103...        2
# 8074   https://cd.lianjia.com/ershoufang/106101874103...        2
# 8421   https://cd.lianjia.com/ershoufang/106101874103...        2
# 8601   https://cd.lianjia.com/ershoufang/106101874103...        2
# 32105  https://cd.lianjia.com/ershoufang/106101874103...        2
# 32333  https://cd.lianjia.com/ershoufang/106101874103...        2
# 41332  https://cd.lianjia.com/ershoufang/106101874103...        2
# 41560  https://cd.lianjia.com/ershoufang/106101874103...        2
# 42083  https://cd.lianjia.com/ershoufang/106101874103...        2
# 42344  https://cd.lianjia.com/ershoufang/106101874103...        2
# 42891  https://cd.lianjia.com/ershoufang/106101874103...        2
# 43071  https://cd.lianjia.com/ershoufang/106101874103...        2
#
#        tradeProperty  farFromStation
# 751                1               2
# 1098               1               1
# 1278               1               2
# 7872               1               1
# 8074               1               2
# 8421               1               1
# 8601               1               2
# 32105              1               1
# 32333              1               2
# 41332              1               1
# 41560              1               2
# 42083              1               1
# 42344              1               2
# 42891              1               1
# 43071              1               2
#
# [15 rows x 21 columns]

# %%
# 分组最小值, 发现真实距离石油大学站541，距离成都医学院635，爬取数据严重不符，所以决定重新爬取
groupby_min_count = dict(list(groupbyed))[(106103345720)]
groupby_min_count
# Out:
#           housecode                name line station residential  area  type  \
# 27253  106103345720  润扬北城1号  精装套三   地铁口  3号线   石油大学站     润扬北城1号   新都城区  3室2厅
#
#        houseArea orientation decoration  ... buildingTime  buildingType  \
# 27253      78.99           南         精装  ...       2013.0            塔楼
#
#       follow  unitPrice  totalPrice                tags  \
# 27253      1    14559.0       115.0  subway:近地铁;vr:VR房源
#
#                                                     href elevator  \
# 27253  https://cd.lianjia.com/ershoufang/106103345720...        2
#
#        tradeProperty  farFromStation
# 27253              1               1
#
# [1 rows x 21 columns]

# %%
drop_duplicates_data = houses.drop_duplicates('housecode')

# %%
houses_by_station = drop_duplicates_data.groupby('station')

# %%
by_staion_count = houses_by_station.size().sort_values(ascending=False)

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

# %%
# 数量分布图
count_bar = (Bar().add_xaxis(by_staion_count.index.tolist()[:10]).add_yaxis('数量',by_staion_count.values.tolist()[:10]))

# %%
count_bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e7648d22a8414745bc0430b6dcd5774d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e7648d22a8414745bc0430b6dcd5774d = echarts.init(
#                     document.getElementById('e7648d22a8414745bc0430b6dcd5774d'), 'white', {renderer: 'canvas'});
#                 var option_e7648d22a8414745bc0430b6dcd5774d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6570\u91cf",
#             "data": [
#                 745,
#                 586,
#                 536,
#                 496,
#                 455,
#                 452,
#                 452,
#                 442,
#                 431,
#                 430
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u6570\u91cf": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u7f8a\u7280\u7acb\u4ea4\u7ad9",
#                 "\u6625\u7199\u8def\u7ad9",
#                 "\u4e00\u54c1\u5929\u4e0b\u7ad9",
#                 "\u4e2d\u575d\u7ad9",
#                 "\u9f99\u722a\u5830\u7ad9",
#                 "\u662d\u89c9\u5bfa\u5357\u8def\u7ad9",
#                 "\u6d8c\u6cc9\u7ad9",
#                 "\u56db\u6cb3\u7ad9",
#                 "\u8700\u6c49\u8def\u4e1c\u7ad9",
#                 "\u6587\u5316\u5bab\u7ad9"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_e7648d22a8414745bc0430b6dcd5774d.setOption(option_e7648d22a8414745bc0430b6dcd5774d);
#         });
#     </script>

# %%
# 均价分布图
by_mean = houses_by_station['unitPrice'].mean().sort_values(ascending=False)

# %%
mean_bar = (Bar().add_xaxis(by_mean.index.tolist()[:10]).add_yaxis('数量',by_mean.round(2).values.tolist()[:10]))
mean_bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="83c14421f6444cc98ddb63b898c12dfa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_83c14421f6444cc98ddb63b898c12dfa = echarts.init(
#                     document.getElementById('83c14421f6444cc98ddb63b898c12dfa'), 'white', {renderer: 'canvas'});
#                 var option_83c14421f6444cc98ddb63b898c12dfa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6570\u91cf",
#             "data": [
#                 39652.63,
#                 38265.85,
#                 37620.43,
#                 32684.52,
#                 31450.82,
#                 29679.32,
#                 29263.66,
#                 27084.06,
#                 26916.13,
#                 26653.72
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u6570\u91cf": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4ea4\u5b50\u5927\u9053\u7ad9",
#                 "\u5e02\u4e00\u533b\u9662\u7ad9",
#                 "\u5b75\u5316\u56ed\u7ad9",
#                 "\u5174\u9686\u6e56\u7ad9",
#                 "\u91d1\u878d\u57ce\u7ad9",
#                 "\u6b66\u6c49\u8def\u7ad9",
#                 "\u4e1c\u5927\u8def\u7ad9",
#                 "\u9526\u6c5f\u5bbe\u9986\u7ad9",
#                 "\u5927\u6e90\u7ad9",
#                 "\u9526\u57ce\u6e56\u7ad9"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_83c14421f6444cc98ddb63b898c12dfa.setOption(option_83c14421f6444cc98ddb63b898c12dfa);
#         });
#     </script>

# %%
by_type = drop_duplicates_data.groupby('type')

# %%
by_type_sort = by_type.size().sort_values(ascending=False)

# %%
type_bar = (Bar().add_xaxis(by_type_sort.index.tolist()[:10]).add_yaxis('户型',by_type_sort.round(2).values.tolist()[:10]))
type_bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5be9fba58f444dc6a5bcde10690cb857" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5be9fba58f444dc6a5bcde10690cb857 = echarts.init(
#                     document.getElementById('5be9fba58f444dc6a5bcde10690cb857'), 'white', {renderer: 'canvas'});
#                 var option_5be9fba58f444dc6a5bcde10690cb857 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6237\u578b",
#             "data": [
#                 6828,
#                 6776,
#                 3982,
#                 3575,
#                 3133,
#                 1968,
#                 873,
#                 458,
#                 285,
#                 112
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6237\u578b"
#             ],
#             "selected": {
#                 "\u6237\u578b": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "3\u5ba42\u5385",
#                 "2\u5ba41\u5385",
#                 "2\u5ba42\u5385",
#                 "3\u5ba41\u5385",
#                 "1\u5ba41\u5385",
#                 "4\u5ba42\u5385",
#                 "1\u5ba40\u5385",
#                 "4\u5ba41\u5385",
#                 "5\u5ba42\u5385",
#                 "1\u5ba42\u5385"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_5be9fba58f444dc6a5bcde10690cb857.setOption(option_5be9fba58f444dc6a5bcde10690cb857);
#         });
#     </script>

# %%
by_type['type'].count().sort_values(ascending=False)
# Out:
# type
# 3室2厅    6828
# 2室1厅    6776
# 2室2厅    3982
# 3室1厅    3575
# 1室1厅    3133
# 4室2厅    1968
# 1室0厅     873
# 4室1厅     458
# 5室2厅     285
# 1室2厅     112
# 4室3厅      59
# 5室3厅      58
# 5室1厅      49
# 6室2厅      48
# 3室3厅      44
# 2室0厅      30
# 6室3厅      20
# 3室0厅      17
# 6室1厅      11
# 7室2厅       9
# 7室3厅       8
# 8室2厅       4
# 4室4厅       3
# 4室0厅       3
# 6室4厅       3
# 7室1厅       2
# 9室3厅       2
# 5室4厅       2
# 0室1厅       1
# 9室4厅       1
# 5室0厅       1
# 2室3厅       1
# 6室0厅       1
# 7室4厅       1
# 8室1厅       1
# 9室2厅       1
# 0室0厅       1
# Name: type, dtype: int64

# %%
drop_duplicates_data['unitPrice'].groupby(drop_duplicates_data['type']).mean()
# Out:
# type
# 0室0厅     9961.000000
# 0室1厅     9970.000000
# 1室0厅    15826.581901
# 1室1厅    16974.282158
# 1室2厅    18813.982143
# 2室0厅    17073.633333
# 2室1厅    17075.877804
# 2室2厅    16969.868157
# 2室3厅    18161.000000
# 3室0厅    18306.000000
# 3室1厅    17934.843916
# 3室2厅    17608.749707
# 3室3厅    17370.295455
# 4室0厅    16916.000000
# 4室1厅    20151.978166
# 4室2厅    19714.914126
# 4室3厅    19224.338983
# 4室4厅    27750.000000
# 5室0厅    13128.000000
# 5室1厅    22591.897959
# 5室2厅    22231.522807
# 5室3厅    22639.413793
# 5室4厅    17570.000000
# 6室0厅    17316.000000
# 6室1厅    18504.727273
# 6室2厅    21843.937500
# 6室3厅    18902.600000
# 6室4厅    19794.000000
# 7室1厅    11948.000000
# 7室2厅    15806.555556
# 7室3厅    26939.000000
# 7室4厅    19802.000000
# 8室1厅    29416.000000
# 8室2厅    20032.750000
# 9室2厅    12191.000000
# 9室3厅    27345.500000
# 9室4厅    63905.000000
# Name: unitPrice, dtype: float64

# %%
dict(list(drop_duplicates_data.groupby('type')))['9室4厅']
# Out:
#          housecode               name          line station residential area  \
# 4216  106101113433  誉峰二期顶楼跃层带花园，对小区中庭  1号线(科学城-韦家碾)    金融城站       誉峰二期   金融城
#
#       type  houseArea orientation decoration  ... buildingTime  buildingType  \
# 4216  9室4厅     297.32          东北         精装  ...       2014.0            板楼
#
#      follow  unitPrice  totalPrice                   tags  \
# 4216      5    63905.0      1900.0  subway:近地铁;five:房本满两年
#
#                                                    href elevator  \
# 4216  https://cd.lianjia.com/ershoufang/106101113433...        2
#
#       tradeProperty  farFromStation
# 4216              1               2
#
# [1 rows x 21 columns]

# %%
dict(list(drop_duplicates_data.groupby('type')))['0室0厅']
# Out:
#           housecode               name line station residential  area  type  \
# 49100  106104069739  德坤新天地 --室--厅 106万  4号线   光华公园站      德坤新天地   珠江新城  0室0厅
#
#        houseArea orientation decoration  ... buildingTime  buildingType  \
# 49100     106.42           南         其他  ...          NaN            塔楼
#
#       follow  unitPrice  totalPrice        tags  \
# 49100      0     9961.0       106.0  subway:近地铁
#
#                                                     href elevator  \
# 49100  https://cd.lianjia.com/ershoufang/106104069739...        2
#
#        tradeProperty  farFromStation
# 49100              1               2
#
# [1 rows x 21 columns]

# %%
drop_duplicates_data['type'].value_counts()
# Out:
# 3室2厅    6828
# 2室1厅    6776
# 2室2厅    3982
# 3室1厅    3575
# 1室1厅    3133
# 4室2厅    1968
# 1室0厅     873
# 4室1厅     458
# 5室2厅     285
# 1室2厅     112
# 4室3厅      59
# 5室3厅      58
# 5室1厅      49
# 6室2厅      48
# 3室3厅      44
# 2室0厅      30
# 6室3厅      20
# 3室0厅      17
# 6室1厅      11
# 7室2厅       9
# 7室3厅       8
# 8室2厅       4
# 4室4厅       3
# 4室0厅       3
# 6室4厅       3
# 5室4厅       2
# 7室1厅       2
# 9室3厅       2
# 0室0厅       1
# 2室3厅       1
# 8室1厅       1
# 6室0厅       1
# 7室4厅       1
# 9室4厅       1
# 0室1厅       1
# 9室2厅       1
# 5室0厅       1
# Name: type, dtype: int64

# %%
drop_duplicates_data.sort_values(['follow'], ascending=False).head()
# Out:
#           housecode                 name line station residential area  type  \
# 52903  106104104127    全兴花园电梯套四户型 房子户型方正  5号线  北站西二路站       全兴花园    沙湾  4室2厅
# 31703  106104036648     世茂玉锦湾带超大平台清水套四出售  3号线    红星桥站    世茂玉锦湾二期   猛追湾  4室2厅
# 57894  106102585532      高新南区 标准套二  户型方正  5号线   九兴大道站        梧桐苑   神仙树  2室1厅
# 57887  106102817847      高新南  方正套二  可上屋顶  5号线   九兴大道站        梧桐苑   神仙树  2室2厅
# 47635  106102894352  精装修 中间楼层 带车位 房东诚心出售  4号线     中坝站     中铁瑞景颐城   外光华  3室1厅
#
#        houseArea orientation decoration  ... buildingTime  buildingType  \
# 52903     154.09           东         其他  ...       2002.0          板塔结合
# 31703     186.00          西南         毛坯  ...       2015.0            板楼
# 57894      61.38         南 北         简装  ...       2000.0            板楼
# 57887      74.00          东南         简装  ...       2000.0            板楼
# 47635      80.11          东北         精装  ...       2013.0            板楼
#
#       follow  unitPrice  totalPrice                              tags  \
# 52903      9    14018.0       216.0    subway:近地铁;vr:VR房源;haskey:随时看房
# 31703      9    30000.0       558.0            subway:近地铁;haskey:随时看房
# 57894      9    15152.0        93.0                subway:近地铁;vr:VR房源
# 57887      9    14190.0       105.0  subway:近地铁;vr:VR房源;taxfree:房本满五年
# 47635      9    24217.0       194.0                subway:近地铁;vr:VR房源
#
#                                                     href elevator  \
# 52903  https://cd.lianjia.com/ershoufang/106104104127...        2
# 31703  https://cd.lianjia.com/ershoufang/106104036648...        2
# 57894  https://cd.lianjia.com/ershoufang/106102585532...        1
# 57887  https://cd.lianjia.com/ershoufang/106102817847...        1
# 47635  https://cd.lianjia.com/ershoufang/106102894352...        2
#
#        tradeProperty  farFromStation
# 52903              1               1
# 31703              1               2
# 57894              1               2
# 57887              1               2
# 47635              1               2
#
# [5 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.bar(by_type_sort.index.tolist()[:10], by_type_sort.round(2).values.tolist()[:10], 0.35, label='type num' )
ax.legend()
plt.show()
