# %%
import pandas as pd
houses = pd.read_csv('../Lianjia_project.csv', names= ['housecode', 'name', 'line', 'station', 'residential', 'area', 'type', 'houseArea',
            'orientation', 'decoration', 'floor', 'buildingTime', 'buildingType', 'follow',
            'unitPrice', 'totalPrice', 'tags', 'href', 'elevator', 'tradeProperty', 'farFromStation'])

# %%
# 经分析具体数据发现，户型数量5室及以上都是可以排除的，不在分析范围之内，要么是别墅，要么是双层，要么是写字楼，“0室0厅”也要排除掉
# houses[int(houses['type'][0])>4]
clear_houses = houses[houses.apply(lambda x: int(x['type'][0]) < 5 and int(x['type'][0]) > 0 and x['houseArea'] < 200,axis=1)]

# %%
# 因为一套房有可能在三个地铁之间，而数据在距离0-500， 500-800重复采集，所以以housecode, station去重
clear_data = clear_houses.drop_duplicates(['housecode', 'station']).reset_index()

# %%
clear_data.head()
# Out:
#    index     housecode                       name          line station  \
# 0      0  106104305279        绿地世纪城标准套一，有装修有家具家电。  1号线(科学城-韦家碾)    韦家碾站
# 1      1  106101436146          绿地世纪城朝南精装横厅套二中高楼层  1号线(科学城-韦家碾)    韦家碾站
# 2      2  106101094541  绿地世纪城标准套二，客厅朝南，位置安静，户型方正。  1号线(科学城-韦家碾)    韦家碾站
# 3      3  106103823860       绿地世纪城标准大套四，户型方正，带车位。  1号线(科学城-韦家碾)    韦家碾站
# 4      4  106101187487         绿地世纪城标准套一，有装修带家具家电  1号线(科学城-韦家碾)    韦家碾站
#
#   residential area  type  houseArea orientation  ... buildingTime  \
# 0      绿地世纪城   驷马桥  1室1厅      50.62           北  ...       2016.0
# 1      绿地世纪城   驷马桥  2室2厅      73.88           南  ...       2016.0
# 2      绿地世纪城   驷马桥  2室1厅      74.00           南  ...       2016.0
# 3      绿地世纪城   驷马桥  4室1厅     121.14           北  ...       2016.0
# 4      绿地世纪城   驷马桥  1室1厅      49.88           北  ...       2016.0
#
#   buildingType  follow unitPrice  totalPrice  \
# 0           塔楼       5   14422.0        73.0
# 1           塔楼       9   17597.0       130.0
# 2           塔楼       9   17568.0       130.0
# 3           塔楼       3   16510.0       200.0
# 4           塔楼       8   15598.0        77.8
#
#                                         tags  \
# 0                         subway:近地铁;vr:VR房源
# 1              subway:近地铁;vr:VR房源;five:房本满两年
# 2                         subway:近地铁;vr:VR房源
# 3             subway:近地铁;vr:VR房源;haskey:随时看房
# 4  subway:近地铁;vr:VR房源;five:房本满两年;haskey:随时看房
#
#                                                 href elevator tradeProperty  \
# 0  https://cd.lianjia.com/ershoufang/106104305279...        2             1
# 1  https://cd.lianjia.com/ershoufang/106101436146...        2             1
# 2  https://cd.lianjia.com/ershoufang/106101094541...        2             1
# 3  https://cd.lianjia.com/ershoufang/106103823860...        2             1
# 4  https://cd.lianjia.com/ershoufang/106101187487...        2             1
#
#    farFromStation
# 0               2
# 1               2
# 2               2
# 3               2
# 4               2
#
# [5 rows x 22 columns]

# %%
clear_data.describe()
# houseArea的数据不正常，max=832186, min=7; unitPrice不正常，max=148045，min=2;totalPrice不正常，min=7,max = 2400
# Out:
#               index     housecode      houseArea  buildingTime        follow  \
# count  50143.000000  5.014300e+04   50143.000000  46050.000000  50143.000000
# mean   37203.718186  1.061031e+11     109.069852   2007.187991      3.091139
# std    20296.287674  9.486901e+05    3716.120951      6.582402      2.466025
# min        0.000000  1.060894e+11       7.160000   1976.000000      0.000000
# 25%    21314.500000  1.061025e+11      67.300000   2003.000000      1.000000
# 50%    37376.000000  1.061034e+11      87.220000   2008.000000      2.000000
# 75%    53779.500000  1.061039e+11     113.005000   2012.000000      5.000000
# max    73898.000000  1.061043e+11  832186.000000   2019.000000      9.000000
#
#            unitPrice    totalPrice      elevator  tradeProperty  \
# count   50143.000000  50143.000000  50143.000000   50143.000000
# mean    17839.799992    168.843707      1.709511       1.061963
# std      6514.973559    110.006316      0.453993       0.350572
# min         2.000000      7.000000      1.000000       1.000000
# 25%     13077.000000     98.000000      1.000000       1.000000
# 50%     16532.000000    141.000000      2.000000       1.000000
# 75%     20952.000000    205.000000      2.000000       1.000000
# max    148045.000000   2400.000000      2.000000       4.000000
#
#        farFromStation
# count    50143.000000
# mean         1.518876
# std          0.499649
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          2.000000

# %%
# 进行数据清理,排除掉面积大于200平方，小于50平方
clear_houses = clear_data[clear_data.apply(lambda x: x['houseArea'] < 200 and x['houseArea'] > 50,axis=1)]
clear_houses
# Out:
#        index     housecode                       name          line station  \
# 0          0  106104305279        绿地世纪城标准套一，有装修有家具家电。  1号线(科学城-韦家碾)    韦家碾站
# 1          1  106101436146          绿地世纪城朝南精装横厅套二中高楼层  1号线(科学城-韦家碾)    韦家碾站
# 2          2  106101094541  绿地世纪城标准套二，客厅朝南，位置安静，户型方正。  1号线(科学城-韦家碾)    韦家碾站
# 3          3  106103823860       绿地世纪城标准大套四，户型方正，带车位。  1号线(科学城-韦家碾)    韦家碾站
# 5          5  106102846143        三环内朝南对中庭套一 不临街 居家安静  1号线(科学城-韦家碾)    韦家碾站
# ...      ...           ...                        ...           ...     ...
# 50138  73894  106103422679          大套三错层，房东诚心出售，价格合适          10号线    刘家碾站
# 50139  73895  106102571560        此房满2年，户型方正，结构好，采光好。          10号线    刘家碾站
# 50140  73896  106103068240      （地铁10号线）地铁口！金三角广场！水电气          10号线    刘家碾站
# 50141  73897  106103689276        轨道交通方便，读书方便，绿道，成都方便          10号线    刘家碾站
# 50142  73898  106103856060            税务局家属区套四，大户型采光好          10号线    刘家碾站
#
#       residential area  type  houseArea orientation  ... buildingTime  \
# 0          绿地世纪城   驷马桥  1室1厅      50.62           北  ...       2016.0
# 1          绿地世纪城   驷马桥  2室2厅      73.88           南  ...       2016.0
# 2          绿地世纪城   驷马桥  2室1厅      74.00           南  ...       2016.0
# 3          绿地世纪城   驷马桥  4室1厅     121.14           北  ...       2016.0
# 5          绿地世纪城   驷马桥  1室1厅      52.98           南  ...       2016.0
# ...           ...  ...   ...        ...         ...  ...          ...
# 50138       市场公寓    新津  3室3厅     146.40           南  ...       2002.0
# 50139     水务局家属区    新津  3室2厅     126.00         南 北  ...       1997.0
# 50140        缤纷城    新津  3室3厅     138.00          东南  ...       2005.0
# 50141    黄鹤大道85号    新津  3室2厅     109.00         东 南  ...          NaN
# 50142     税务局家属院    新津  4室2厅     183.78          西北  ...          NaN
#
#       buildingType  follow unitPrice  totalPrice  \
# 0               塔楼       5   14422.0        73.0
# 1               塔楼       9   17597.0       130.0
# 2               塔楼       9   17568.0       130.0
# 3               塔楼       3   16510.0       200.0
# 5               塔楼       4   14346.0        76.0
# ...            ...     ...       ...         ...
# 50138         暂无数据       0    9563.0       140.0
# 50139           板楼       1    8096.0       102.0
# 50140         暂无数据       1   10870.0       150.0
# 50141         板塔结合       0    9634.0       105.0
# 50142         暂无数据       2    7618.0       140.0
#
#                                    tags  \
# 0                    subway:近地铁;vr:VR房源
# 1         subway:近地铁;vr:VR房源;five:房本满两年
# 2                    subway:近地铁;vr:VR房源
# 3        subway:近地铁;vr:VR房源;haskey:随时看房
# 5      subway:近地铁;vr:VR房源;taxfree:房本满五年
# ...                                 ...
# 50138    subway:近地铁;vr:VR房源;haskey:随时看房
# 50139                subway:近地铁;vr:VR房源
# 50140                subway:近地铁;vr:VR房源
# 50141                subway:近地铁;vr:VR房源
# 50142                subway:近地铁;vr:VR房源
#
#                                                     href elevator  \
# 0      https://cd.lianjia.com/ershoufang/106104305279...        2
# 1      https://cd.lianjia.com/ershoufang/106101436146...        2
# 2      https://cd.lianjia.com/ershoufang/106101094541...        2
# 3      https://cd.lianjia.com/ershoufang/106103823860...        2
# 5      https://cd.lianjia.com/ershoufang/106102846143...        2
# ...                                                  ...      ...
# 50138  https://cd.lianjia.com/ershoufang/106103422679...        1
# 50139  https://cd.lianjia.com/ershoufang/106102571560...        1
# 50140  https://cd.lianjia.com/ershoufang/106103068240...        1
# 50141  https://cd.lianjia.com/ershoufang/106103689276...        1
# 50142  https://cd.lianjia.com/ershoufang/106103856060...        1
#
#       tradeProperty  farFromStation
# 0                 1               2
# 1                 1               2
# 2                 1               2
# 3                 1               2
# 5                 1               2
# ...             ...             ...
# 50138             1               1
# 50139             1               1
# 50140             1               1
# 50141             1               1
# 50142             1               1
#
# [44875 rows x 22 columns]

# %%
clear_houses.describe()
# 此时数据就正常了许多
# Out:
#               index     housecode     houseArea  buildingTime        follow  \
# count  44875.000000  4.487500e+04  44875.000000  41271.000000  44875.000000
# mean   37047.825359  1.061031e+11     95.789450   2007.365971      3.104156
# std    20184.386231  9.457276e+05     30.604445      6.611700      2.468950
# min        0.000000  1.060894e+11     50.010000   1978.000000      0.000000
# 25%    21038.500000  1.061025e+11     74.010000   2002.000000      1.000000
# 50%    37407.000000  1.061034e+11     88.900000   2009.000000      2.000000
# 75%    53516.500000  1.061039e+11    115.940000   2012.000000      5.000000
# max    73898.000000  1.061043e+11    199.860000   2019.000000      9.000000
#
#           unitPrice    totalPrice      elevator  tradeProperty  farFromStation
# count  44875.000000  44875.000000  44875.000000   44875.000000    44875.000000
# mean   17899.197816    174.187236      1.704869       1.060992        1.527019
# std     6423.791103     96.455236      0.456107       0.342762        0.499275
# min     5164.000000     36.000000      1.000000       1.000000        1.000000
# 25%    13111.500000    108.000000      1.000000       1.000000        1.000000
# 50%    16691.000000    150.000000      2.000000       1.000000        2.000000
# 75%    21088.000000    210.000000      2.000000       1.000000        2.000000
# max    61195.000000    950.000000      2.000000       4.000000        2.000000

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

# %%
# 数量分布图
groupby_station = clear_houses.drop_duplicates('housecode').groupby('station')['station'].count().sort_values(ascending=False)
count_bar = Bar().add_xaxis(groupby_station.index.tolist()).add_yaxis('数量',groupby_station.values.tolist()).set_global_opts(datazoom_opts = {'is_show': True})
count_bar.render_notebook()
# 数量最多的前10个地铁站 一品天下，蜀汉东路，西南交大，春熙路，金沙博物馆，羊犀立交，东门大桥，抚琴站，文化宫，四河站  
# 发现前十大主要集中在成都的西北方向，比如一品天下，蜀汉东路，金沙博物馆，羊犀立交，抚琴站，文化宫， 
# 其次是春熙路，东门大桥，太升南路，市二医院，
# 为什么这些地方二手房那么多，需要思考
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-8a28fa7db73a> in <module>
#       1 # 数量分布图
#       2 groupby_station = clear_houses.drop_duplicates('housecode').groupby('station')['station'].count().sort_values(ascending=False)
# ----> 3 count_bar = Bar().add_xaxis(groupby_station.index.tolist()).add_yaxis('数量',groupby_station.values.tolist()).set_global_opts(datazoom_opts = {'is_show': True})
#       4 count_bar.render_notebook()
#       5 # 数量最多的前10个地铁站 一品天下，蜀汉东路，西南交大，春熙路，金沙博物馆，羊犀立交，东门大桥，抚琴站，文化宫，四河站
#
# NameError: name 'Bar' is not defined

# %%
# 不同户型的数量分布
by_type_sort = clear_data.groupby('type')['type'].count().sort_values(ascending=False)
type_bar = (Bar().add_xaxis(by_type_sort.index.tolist()).add_yaxis('数量',by_type_sort.round(2).values.tolist()))
type_bar.render_notebook()
# 户型分三个Level，第一level是“二室一厅”，“三室二厅”，第二level是“二室二厅”“三室一厅”“一室一厅”， 第三level就是余下的
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9a4e3f1791c84e2d99c03c5bad17ef82" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9a4e3f1791c84e2d99c03c5bad17ef82 = echarts.init(
#                     document.getElementById('9a4e3f1791c84e2d99c03c5bad17ef82'), 'white', {renderer: 'canvas'});
#                 var option_9a4e3f1791c84e2d99c03c5bad17ef82 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6570\u91cf",
#             "data": [
#                 12771,
#                 11540,
#                 7060,
#                 6563,
#                 5830,
#                 3239,
#                 1848,
#                 779,
#                 212,
#                 101,
#                 78,
#                 68,
#                 38,
#                 8,
#                 6,
#                 2
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u6570\u91cf": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2\u5ba41\u5385",
#                 "3\u5ba42\u5385",
#                 "2\u5ba42\u5385",
#                 "3\u5ba41\u5385",
#                 "1\u5ba41\u5385",
#                 "4\u5ba42\u5385",
#                 "1\u5ba40\u5385",
#                 "4\u5ba41\u5385",
#                 "1\u5ba42\u5385",
#                 "4\u5ba43\u5385",
#                 "3\u5ba43\u5385",
#                 "2\u5ba40\u5385",
#                 "3\u5ba40\u5385",
#                 "4\u5ba44\u5385",
#                 "4\u5ba40\u5385",
#                 "2\u5ba43\u5385"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_9a4e3f1791c84e2d99c03c5bad17ef82.setOption(option_9a4e3f1791c84e2d99c03c5bad17ef82);
#         });
#     </script>

# %%
# 地铁站的单价平均价格分布
unitPrice_by_station_sort = clear_data.groupby('station')['unitPrice'].mean().round(2).sort_values(ascending=False)
type_bar = (Bar().add_xaxis(unitPrice_by_station_sort.index.tolist()).add_yaxis('单价',unitPrice_by_station_sort.values.tolist()).set_global_opts(datazoom_opts = {'is_show': True}))
type_bar.render_notebook()
# 最贵的都在南边，像锦城大道，锦城广场，交子大道，孵化园，金融城，高新站，市一医院，锦城湖，这些地铁站都在一起  
# 其次是中部向东附近，像天府广场，春熙路，锦江宾馆，人民公园，东门大桥，牛市口
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4c77713e6fcc46549466b50da0d8cdcf" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4c77713e6fcc46549466b50da0d8cdcf = echarts.init(
#                     document.getElementById('4c77713e6fcc46549466b50da0d8cdcf'), 'white', {renderer: 'canvas'});
#                 var option_4c77713e6fcc46549466b50da0d8cdcf = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5355\u4ef7",
#             "data": [
#                 38221.62,
#                 36946.0,
#                 36510.02,
#                 31643.92,
#                 31062.91,
#                 29412.13,
#                 27409.25,
#                 26686.76,
#                 26434.23,
#                 26190.92,
#                 26087.61,
#                 25811.37,
#                 25174.11,
#                 24956.52,
#                 24343.43,
#                 24109.68,
#                 24089.81,
#                 23916.2,
#                 23848.78,
#                 23625.36,
#                 23436.92,
#                 23421.75,
#                 23013.25,
#                 22866.19,
#                 22591.58,
#                 22581.0,
#                 22401.36,
#                 22312.9,
#                 22126.18,
#                 21705.05,
#                 21473.92,
#                 21215.67,
#                 21204.82,
#                 21104.28,
#                 20851.35,
#                 20705.37,
#                 20695.49,
#                 20640.72,
#                 20640.37,
#                 20483.85,
#                 20310.46,
#                 20194.29,
#                 20104.62,
#                 20056.91,
#                 19693.48,
#                 19611.71,
#                 19586.34,
#                 19567.24,
#                 19393.44,
#                 19340.79,
#                 19270.11,
#                 19200.22,
#                 19180.68,
#                 19150.62,
#                 19094.5,
#                 18921.52,
#                 18889.32,
#                 18693.85,
#                 18669.65,
#                 18666.49,
#                 18590.14,
#                 18524.59,
#                 18458.2,
#                 18449.27,
#                 18330.2,
#                 18280.3,
#                 18206.14,
#                 18000.21,
#                 17940.55,
#                 17924.14,
#                 17861.18,
#                 17804.21,
#                 17713.61,
#                 17574.01,
#                 17445.36,
#                 17391.27,
#                 17375.99,
#                 17333.42,
#                 17302.52,
#                 17267.91,
#                 17145.87,
#                 17142.2,
#                 17004.45,
#                 17000.25,
#                 16809.21,
#                 16792.22,
#                 16760.87,
#                 16719.47,
#                 16686.15,
#                 16594.13,
#                 16550.19,
#                 16542.59,
#                 16487.57,
#                 16476.85,
#                 16462.38,
#                 16388.47,
#                 16340.0,
#                 16263.2,
#                 16200.59,
#                 16096.25,
#                 16057.79,
#                 16019.52,
#                 16017.6,
#                 16012.69,
#                 15764.56,
#                 15749.75,
#                 15720.55,
#                 15719.34,
#                 15656.09,
#                 15610.62,
#                 15568.09,
#                 15563.57,
#                 15511.19,
#                 15458.04,
#                 15367.18,
#                 15256.32,
#                 15246.26,
#                 15195.87,
#                 15112.75,
#                 15074.79,
#                 15073.07,
#                 14921.85,
#                 14913.55,
#                 14810.47,
#                 14744.19,
#                 14724.25,
#                 14694.88,
#                 14647.69,
#                 14347.49,
#                 14323.49,
#                 14239.89,
#                 14182.86,
#                 14179.68,
#                 14078.13,
#                 13963.19,
#                 13809.42,
#                 13774.08,
#                 13665.76,
#                 13607.23,
#                 13091.93,
#                 12958.81,
#                 12778.22,
#                 12541.2,
#                 12539.98,
#                 12526.37,
#                 12364.68,
#                 12346.0,
#                 12335.33,
#                 11959.11,
#                 11775.65,
#                 11767.36,
#                 11278.82,
#                 11177.96,
#                 11136.72,
#                 11110.2,
#                 11087.42,
#                 11072.8,
#                 11062.0,
#                 10993.18,
#                 10617.64,
#                 10543.03,
#                 10159.75,
#                 10094.83,
#                 10085.02,
#                 10016.61,
#                 9980.45,
#                 9942.68,
#                 9808.8,
#                 9724.76,
#                 9684.05,
#                 9606.89,
#                 9272.52,
#                 8670.08
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5355\u4ef7"
#             ],
#             "selected": {
#                 "\u5355\u4ef7": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u9526\u57ce\u5927\u9053\u7ad9",
#                 "\u9526\u57ce\u5e7f\u573a\u7ad9",
#                 "\u4ea4\u5b50\u5927\u9053\u7ad9",
#                 "\u5174\u9686\u6e56\u7ad9",
#                 "\u5b75\u5316\u56ed\u7ad9",
#                 "\u6b66\u6c49\u8def\u7ad9",
#                 "\u91d1\u878d\u57ce\u7ad9",
#                 "\u5e02\u4e00\u533b\u9662\u7ad9",
#                 "\u5927\u6e90\u7ad9",
#                 "\u9526\u57ce\u6e56\u7ad9",
#                 "\u4e1c\u5927\u8def\u7ad9",
#                 "\u9526\u6c5f\u5bbe\u9986\u7ad9",
#                 "\u5929\u5e9c\u5e7f\u573a\u7ad9",
#                 "\u6625\u7199\u8def\u7ad9",
#                 "\u77f3\u7f8a\u7acb\u4ea4\u7ad9",
#                 "\u56db\u5ddd\u5e08\u5927\u7ad9",

# %%
# 看看哪里的房子最受欢迎
follow_by_station_sort = clear_data.groupby('station')['follow'].mean().round(2).sort_values(ascending=False)
type_bar = (Bar().add_xaxis(follow_by_station_sort.index.tolist()).add_yaxis('单价',follow_by_station_sort.values.tolist()).set_global_opts(datazoom_opts = {'is_show': True}))
type_bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4a89e38018b84f738bf77fdf9ce2e859" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4a89e38018b84f738bf77fdf9ce2e859 = echarts.init(
#                     document.getElementById('4a89e38018b84f738bf77fdf9ce2e859'), 'white', {renderer: 'canvas'});
#                 var option_4a89e38018b84f738bf77fdf9ce2e859 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5355\u4ef7",
#             "data": [
#                 5.0,
#                 4.27,
#                 4.08,
#                 4.07,
#                 3.75,
#                 3.7,
#                 3.61,
#                 3.6,
#                 3.6,
#                 3.55,
#                 3.54,
#                 3.53,
#                 3.51,
#                 3.49,
#                 3.49,
#                 3.48,
#                 3.44,
#                 3.42,
#                 3.41,
#                 3.37,
#                 3.36,
#                 3.36,
#                 3.36,
#                 3.35,
#                 3.35,
#                 3.34,
#                 3.33,
#                 3.33,
#                 3.33,
#                 3.31,
#                 3.31,
#                 3.3,
#                 3.3,
#                 3.29,
#                 3.29,
#                 3.29,
#                 3.28,
#                 3.28,
#                 3.28,
#                 3.26,
#                 3.25,
#                 3.24,
#                 3.24,
#                 3.24,
#                 3.24,
#                 3.23,
#                 3.23,
#                 3.23,
#                 3.23,
#                 3.23,
#                 3.21,
#                 3.21,
#                 3.21,
#                 3.2,
#                 3.2,
#                 3.2,
#                 3.2,
#                 3.19,
#                 3.18,
#                 3.18,
#                 3.17,
#                 3.17,
#                 3.17,
#                 3.16,
#                 3.16,
#                 3.16,
#                 3.15,
#                 3.14,
#                 3.14,
#                 3.14,
#                 3.14,
#                 3.14,
#                 3.14,
#                 3.14,
#                 3.13,
#                 3.13,
#                 3.13,
#                 3.13,
#                 3.11,
#                 3.11,
#                 3.11,
#                 3.1,
#                 3.1,
#                 3.1,
#                 3.1,
#                 3.09,
#                 3.09,
#                 3.09,
#                 3.08,
#                 3.08,
#                 3.08,
#                 3.08,
#                 3.08,
#                 3.06,
#                 3.06,
#                 3.06,
#                 3.05,
#                 3.05,
#                 3.05,
#                 3.04,
#                 3.04,
#                 3.04,
#                 3.03,
#                 3.03,
#                 3.03,
#                 3.02,
#                 3.02,
#                 3.02,
#                 3.02,
#                 3.02,
#                 3.01,
#                 3.01,
#                 3.0,
#                 3.0,
#                 3.0,
#                 3.0,
#                 2.99,
#                 2.99,
#                 2.99,
#                 2.98,
#                 2.98,
#                 2.97,
#                 2.97,
#                 2.96,
#                 2.96,
#                 2.95,
#                 2.95,
#                 2.94,
#                 2.94,
#                 2.94,
#                 2.92,
#                 2.92,
#                 2.92,
#                 2.91,
#                 2.9,
#                 2.9,
#                 2.88,
#                 2.88,
#                 2.88,
#                 2.88,
#                 2.88,
#                 2.87,
#                 2.87,
#                 2.87,
#                 2.86,
#                 2.83,
#                 2.81,
#                 2.8,
#                 2.78,
#                 2.78,
#                 2.76,
#                 2.75,
#                 2.75,
#                 2.75,
#                 2.75,
#                 2.73,
#                 2.68,
#                 2.64,
#                 2.62,
#                 2.6,
#                 2.58,
#                 2.52,
#                 2.48,
#                 2.47,
#                 2.45,
#                 2.44,
#                 2.38,
#                 2.36,
#                 2.18,
#                 1.73,
#                 1.43,
#                 1.0,
#                 0.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5355\u4ef7"
#             ],
#             "selected": {
#                 "\u5355\u4ef7": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u9526\u57ce\u5e7f\u573a\u7ad9",
#                 "\u4e5d\u9053\u5830\u7ad9",
#                 "\u5174\u9686\u6e56\u7ad9",
#                 "\u6210\u90fd\u884c\u653f\u5b66\u9662\u7ad9",
#                 "\u706b\u8f66\u5357\u7ad9\u7ad9",
#                 "\u5929\u5e9c\u4e94\u8857\u7ad9",
#                 "\u4e1c\u5927\u8def\u7ad9",
#                 "\u534e\u5174\u7ad9",
#                 "\u5347\u4ed9\u6e56\u7ad9",
#                 "\u4e07\u5e74\u573a\u7ad9",
#                 "\u53cc\u6865\u8def\u7ad9",
#                 "\u4e1c\u5761\u8def\u7ad9",
#                 "\u725b\u5e02\u53e3\u7ad9",
#                 "\u5e7f\u798f\u7ad9",
#                 "\u6b66\u6c49\u8def\u7ad9",
#                 "\u56db\u5ddd\u5e08\u5927\u7ad9",
#                 "\u9526\u6c5f\u5bbe\u9986\u7ad9",
#                 "\u6210\u6e1d\u7acb\u4ea4\u7ad9",
#                 "\u534e\u897f\u575d\u7ad9",
#                 "\u60e0\u738b\u9675\u7ad9",
#                 "\u4e1c\u5347\u7ad9",
#                 "\u78e8\u5b50\u6865\u7ad9",
#                 "\u91d1\u534e\u5bfa\u4e1c\u8def\u7ad9",
#                 "\u592a\u5e73\u56ed\u7ad9",
#                 "\u9752\u7f8a\u5bab\u7ad9",
#                 "\u5927\u6e90\u7ad9",
#                 "\u7701\u9aa8\u79d1\u533b\u9662\u7ad9",
#                 "\u6625\u7199\u8def\u7ad9",
#                 "\u9526\u57ce\u5927\u9053\u7ad9",
#                 "\u7ea2\u724c\u697c\u7ad9",
#                 "\u8863\u51a0\u5e99\u7ad9",

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

# %%
f, ax1 = plt.subplots(figsize=(20,5))
# 只展示总价的平均价格最大的前10个
max_total_station = clear_data.groupby('station')['totalPrice'].mean().sort_values(ascending=False)[:10].index
sns.boxplot(x='station', y='totalPrice', data=clear_data[clear_data.station.isin(max_total_station)], ax=ax1)
ax1.set_title('成都各地铁站二手房房屋总价')
ax1.set_xlabel('区域')
ax1.set_ylabel('房屋总价')
plt.show()
# 总价的地铁站分布和均价的地铁站分布相似，而且价格变化大的也是这些地方

# %% [markdown]
# ## 看面积分布
# f, [ax1,ax2] = plt.subplots(1, 2, figsize=(16, 6))
# # 房屋面积
# sns.distplot(clear_data['houseArea'], ax=ax1, color='r')
# sns.kdeplot(clear_data['houseArea'], shade=True, ax=ax1)
# ax1.set_xlabel('面积')
#
# # 房屋面积和价格的关系
# # sns.regplot(x='houseArea', y='totalPrice', data=clear_data, ax=ax2)
# # ax2.set_xlabel('面积')
# # ax2.set_ylabel('总价')
# plt.show()
